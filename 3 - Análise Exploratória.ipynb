# %%
import pandas as pd
from funcoes import plot_safra_bad_rate,resumo_estatistico,grafico_percentual_valores_ausentes,matriz_correlacao,histograma_variaveis_numericas

# %%
treino_selecionado = pd.read_csv("treino_selecionada.csv")

# %%
plot_safra_bad_rate(treino_selecionado, safra_col="safra", inadimplente_col="y", bad_rate_min=0, bad_rate_max=0.5)
# Out:
#     safra  contagem  total_maus  total_bons   badrate
# 0  201401       854         296         558  0.346604
# 1  201402       898         281         617  0.312918
# 2  201403       873         221         652  0.253150
# 3  201404       955         246         709  0.257592
# 4  201405       972         245         727  0.252058
# 5  201406       902         238         664  0.263858
# 6  201407       968         269         699  0.277893
# 7  201408       912         257         655  0.281798
# 8  201409       877         263         614  0.299886

# %%
grafico_percentual_valores_ausentes(treino_selecionado)

# %%
matriz_correlacao(treino_selecionado.iloc[:, 2:15])

# %%
resumo_estatistico(treino_selecionado.iloc[:,3:10])
# Out:
# 📌 Resumo Estatístico das Variáveis Numéricas:
#              VAR_1       VAR_72        VAR_53        VAR_65          VAR_6  \
# count  7902.000000  8148.000000   7700.000000   6543.000000    8148.000000
# mean     36.328904   157.259082   2318.682791   1227.048458    1456.683112
# std      49.229232   299.633977   2348.741672   1443.941138    6860.989218
# min       0.000000  -104.000000     19.380000      0.000000     -47.000000
# 25%       0.000000     8.000000    940.612500    374.325000     446.000000
# 50%      18.000000    52.000000   1600.000000    757.990000     865.500000
# 75%      51.000000   182.000000   3000.000000   1457.905000    1975.250000
# max     208.000000  3652.000000  28002.480000  12245.710000  432895.000000
#
#              VAR_17        VAR_30
# count   4823.000000   8171.000000
# mean    2257.478777   1560.992292
# std     2101.385394   1344.513618
# min       26.000000    150.000000
# 25%     1000.000000    787.825000
# 50%     1600.000000   1100.000000
# ...
