# %%
import pandas as pd
from funcoes import plot_safra_bad_rate,resumo_estatistico,grafico_percentual_valores_ausentes,matriz_correlacao,histograma_variaveis_numericas

# %%
train_selecionada = pd.read_csv("train_selecionada.csv")

# %%
plot_safra_bad_rate(train_selecionada, safra_col="safra", inadimplente_col="y", bad_rate_min=0, bad_rate_max=0.5)
# Out:
#     safra  contagem  total_maus  total_bons   badrate
# 0  201401       702         247         455  0.351852
# 1  201402       709         213         496  0.300423
# 2  201403       701         175         526  0.249643
# 3  201404       754         195         559  0.258621
# 4  201405       772         200         572  0.259067
# 5  201406       715         199         516  0.278322
# 6  201407       777         218         559  0.280566
# 7  201408       727         196         531  0.269601
# 8  201409       711         210         501  0.295359

# %%
grafico_percentual_valores_ausentes(train_selecionada)
# Out:
# ✅ Nenhuma variável possui valores ausentes.

# %%
matriz_correlacao(train_selecionada.iloc[:, 2:15])

# %%
resumo_estatistico(train_selecionada.iloc[:,3:10])
# Out:
# 📌 Resumo Estatístico das Variáveis Numéricas:
#              VAR_1       VAR_32       VAR_52       VAR_45       VAR_24  \
# count  6568.000000  6568.000000  6568.000000  6568.000000  6568.000000
# mean     35.910627     0.115253   226.696273   335.965023   348.033138
# std      48.509780     0.027803   162.639187   226.515302   239.918529
# min       0.000000    -0.103405     0.500000     0.990000     0.980000
# 25%       0.000000     0.090634   188.065000   289.932500   253.082500
# 50%      18.000000     0.133833   197.970000   298.535000   305.920000
# 75%      49.000000     0.133833   205.165000   305.902500   363.092500
# max     208.000000     0.133833  3351.500000  3049.740000  2716.730000
#
#             VAR_72       VAR_44
# count  6568.000000  6568.000000
# mean    156.070493     4.028305
# std     298.408516     4.812548
# min    -104.000000     0.000000
# 25%       8.000000     0.000000
# 50%      52.000000     1.000000
# 75%     179.250000     9.000000
# ...
